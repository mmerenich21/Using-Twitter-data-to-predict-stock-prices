# %%
import pandas as pd
import tweepy

# install snscrape (https://github.com/JustAnotherArchivist/snscrape)

# %%
snscrape twitter-search '$PFE since:2020-03-01 until:2020-03-15' >PFE_tweets_1st_15th_March.txt
snscrape twitter-search '$PFE since:2020-03-16 until:2020-03-31' >PFE_tweets_16th_31st_March.txt
snscrape twitter-search '$PFE since:2020-04-01 until:2020-04-15' >PFE_tweets_1st_15th_April.txt
snscrape twitter-search '$PFE since:2020-04-16 until:2020-04-30' >PFE_tweets_16th_30th_April.txt
snscrape twitter-search '$PFE since:2020-05-01 until:2020-05-15' >PFE_tweets_1st_15th_May.txt
snscrape twitter-search '$PFE since:2020-05-16 until:2020-05-31' >PFE_tweets_16th_31st_May.txt
snscrape twitter-search '$PFE since:2020-06-01 until:2020-06-15' >PFE_tweets_1st_15th_June.txt
snscrape twitter-search '$PFE since:2020-06-16 until:2020-06-30' >PFE_tweets_16th_30th_June.txt
snscrape twitter-search '$PFE since:2020-07-01 until:2020-07-15' >PFE_tweets_1st_15th_July.txt
snscrape twitter-search '$PFE since:2020-07-16 until:2020-07-31' >PFE_tweets_16th_31st_July.txt
snscrape twitter-search '$PFE since:2020-08-01 until:2020-08-15' >PFE_tweets_1st_15th_August.txt
snscrape twitter-search '$PFE since:2020-08-16 until:2020-08-31' >PFE_tweets_16th_31st_August.txt
snscrape twitter-search '$PFE since:2020-09-01 until:2020-09-15' >PFE_tweets_1st_15th_September.txt
snscrape twitter-search '$PFE since:2020-09-16 until:2020-09-30' >PFE_tweets_16th_30th_September.txt
snscrape twitter-search '$PFE since:2020-10-01 until:2020-10-15' >PFE_tweets_1st_15th_October.txt
snscrape twitter-search '$PFE since:2020-10-16 until:2020-10-31' >PFE_tweets_16th_31st_October.txt
snscrape twitter-search '$PFE since:2020-11-01 until:2020-11-19' >PFE_tweets_1st_19th_November.txt
snscrape twitter-search '$PFE since:2020-03-15 until:2020-03-16' >PFE_tweets_15th_March.txt
snscrape twitter-search '$PFE since:2020-03-31 until:2020-04-01' >PFE_tweets_31st_March.txt
snscrape twitter-search '$PFE since:2020-04-15 until:2020-04-16' >PFE_tweets_15th_April.txt
snscrape twitter-search '$PFE since:2020-04-30 until:2020-05-01' >PFE_tweets_30th_April.txt
snscrape twitter-search '$PFE since:2020-05-15 until:2020-05-16' >PFE_tweets_15th_May.txt
snscrape twitter-search '$PFE since:2020-05-31 until:2020-06-01' >PFE_tweets_31st_May.txt
snscrape twitter-search '$PFE since:2020-06-15 until:2020-06-16' >PFE_tweets_15th_June.txt
snscrape twitter-search '$PFE since:2020-06-30 until:2020-07-01' >PFE_tweets_30th_June.txt
snscrape twitter-search '$PFE since:2020-07-15 until:2020-07-16' >PFE_tweets_15th_July.txt
snscrape twitter-search '$PFE since:2020-07-31 until:2020-08-01' >PFE_tweets_31st_July.txt
snscrape twitter-search '$PFE since:2020-08-15 until:2020-08-16' >PFE_tweets_15th_August.txt
snscrape twitter-search '$PFE since:2020-08-31 until:2020-09-01' >PFE_tweets_31st_August.txt
snscrape twitter-search '$PFE since:2020-09-15 until:2020-09-16' >PFE_tweets_15th_September.txt
snscrape twitter-search '$NKE since:2020-10-01 until:2020-10-16' >NKE_tweets_1st_15th_October.txt
snscrape twitter-search '$NKE since:2020-10-16 until:2020-11-01' >NKE_tweets_16th_31st_October.txt
snscrape twitter-search '$NKE since:2020-11-01 until:2020-11-20' >NKE_tweets_1st_19th_November.txt

# %%
# authentication keys for twitter API

consumer_key = "jFRNwKUpGnRntu5mYTrSsTtBz" 
consumer_secret = "6AJLdu6fwPgmzsZ5WTHuc0rr5tPBjygXHfTH26CwU36mN60oK4" 
access_token= "770804018-qTE1w3dpwDf9a56oJb6zm6bVMY0TeJxp8GbJ8YpH" 
access_token_secret = "A1sRCcjrqTvrSBgb0D5vwfqih4yn11YXFlRt215VrPXk0"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# reading the URLS into a pandas dataframe

tweet_url = pd.read_csv("C:\\Windows\\System32\\NKE_tweets_1st_19th_November.txt", 'rb' , engine='python', index_col= None, header = None, names = ["links"])
tweet_url
# Out:
#                                                   links
# 0     ÿþhttps://twitter.com/st...
# 1
# 2     https://twitter.com/bil...
# 3
# 4     https://twitter.com/hin...
# ...                                                 ...
# 2658  https://twitter.com/Foc...
# 2659
# 2660  https://twitter.com/Sto...
# 2661
# 2662
#
# [2663 rows x 1 columns]

# %%
# Stripping the tweet_ids

af = lambda x: x["links"].split("/")[-1]
tweet_url['id'] = tweet_url.apply(af, axis=1)
tweet_url
# Out:
#                                                   links  \
# 0     ÿþhttps://twitter.com/st...
# 1
# 2     https://twitter.com/bil...
# 3
# 4     https://twitter.com/hin...
# ...                                                 ...
# 2658  https://twitter.com/Foc...
# 2659
# 2660  https://twitter.com/Sto...
# 2661
# 2662
#
#                                            id
# 0     1329562096766488576
# 1
# 2     1329557777283489794
# 3
# 4     1329551441762119680
# ...                                       ...
# 2658  1322785455360921600
# 2659
# 2660  1322772896905785346
# 2661
# 2662
#
# [2663 rows x 2 columns]

# %%
# converting the ids into a list for using in Tweepy
ids = tweet_url['id'].tolist()
ids[:10]
ids2 = []

for i in ids:
    b = i.replace('\x00', '')
    ids2.append(b)

ids2[:10]
# Out:
# ['1329562096766488576',
#  '',
#  '1329557777283489794',
#  '',
#  '1329551441762119680',
#  '',
#  '1329548754568011788',
#  '',
#  '1329540272754049024',
#  '']

# %%
# encountered errors when pulling all tweets at once, hence dividing into chunks

total_count = len(ids2)
chunks = (total_count - 1) // 50 + 1

# %%
# function to pull the tweets using tweepy

def fetch_tw(ids2):
    list_of_tw_status = api.statuses_lookup(ids2, tweet_mode= "extended")
    empty_data = pd.DataFrame()
    for status in list_of_tw_status:
            tweet_elem = {"tweet_id": status.id,
                     "screen_name": status.user.screen_name,
                     "tweet":status.full_text,
                     "date":status.created_at}
            empty_data = empty_data.append(tweet_elem, ignore_index = True)
    
    # appending data into a csv file (each cashtag should have one file)
    empty_data.to_csv("C:\\Users\\mmere\\Documents\\Drexel\\Masters\\DSCI 631\\Project\\data\\Nike.csv", mode="a")

# %%
# looping through the above loop again to pull tweets in chunks

for i in range(chunks):
        batch = ids2[i*50:(i+1)*50]
        result = fetch_tw(batch)
